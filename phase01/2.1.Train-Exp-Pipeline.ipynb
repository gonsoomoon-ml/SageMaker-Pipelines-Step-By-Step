# %% [markdown]
# # [모듈 2.1] 모델 훈련 스텝 개발 (SageMaker Model Building Pipeline 훈련 스텝)
#
# 이 노트북은 아래와 같은 목차로 진행 됩니다. 전체를 모두 실행시에 완료 시간은 약 5분-10분 소요 됩니다.
#
# - 0. 모델 훈련 개요
# - 1. 데이터 세트 로딩 및 기본 훈련 변수 설정
# - 2. 모델 훈련 코드 확인
# - 3. 모델 훈련 스텝 개발 및 실행
#     - 아래의 3단계를 진행하여 SageMaker Model Building Pipeline 에서 훈련 스텝 개발 함. 아래의 (1), (2) 단계는 옵션이지만, 실제 현업 개발시에 필요한 단계이기에 실행을 권장 드립니다.
#         - (1) **[로컬 노트북 인스턴스]**에서 다커 컨테이너로 훈련 코드 실행 (로컬 모드로 불리움)
#         - (2) 세이지메이커 호스트 모드(로컬 다커 컨테이너 사용) 및 실험(Experiment)사용하여 훈련 코드 실행
#         - (3) [필수] SageMaker Model Building Pipeline 에서 모델 훈련 스텝 개발 및 실행
#
# ---

# %% [markdown]
# # 0. 모델 훈련 개요

# %% [markdown]
# # 1. 데이터 세트 로딩 및 기본 훈련 변수 설정
# - 이전 단계(전처리)에서 결과 파일을 로딩 합니다. 실제 훈련에 제공되는 데이터를 확인하기 위함 입니다.
# ---

# %%
import boto3
import sagemaker
import pandas as pd
import os

#region = boto3.Session().region_name
sagemaker_session = sagemaker.session.Session()
role = sagemaker.get_execution_role()
sm_client = boto3.client("sagemaker")

# region = sagemaker.Session().boto_region_name
# print("Using AWS Region: {}".format(region))

# %store -r 
# 노트북에 저장되어 있는 변수를 보기 위해서는 주석을 제거하고 실행하시면 됩니다.
# %store

# %%
! aws s3 ls {train_preproc_data_uri} --recursive
# Out:
# 2021-07-24 06:51:43     767663 sagemaker-pipeline-step-by-step-phase01/preporc/train.csv

# %%
train_prep_df = pd.read_csv(train_preproc_data_uri)
train_prep_df
# Out:
#       customer_age  months_as_customer  num_claims_past_year  \
# 0               54                  94                     0
# 1               41                 165                     0
# 2               57                 155                     0
# 3               39                  80                     0
# 4               39                  60                     0
# ...            ...                 ...                   ...
# 4495            55                 151                     0
# 4496            47                 155                     0
# 4497            34                 177                     0
# 4498            61                 268                     0
# 4499            23                  26                     0
#
#       num_insurers_past_5_years  policy_deductable  policy_annual_premium  \
# 0                             1                750                   3000
# 1                             1                750                   2950
# 2                             1                750                   3000
# 3                             1                750                   3000
# 4                             1                750                   3000
# ...                         ...                ...                    ...
# 4495                          1                750                   3000
# 4496                          1                750                   3000
# 4497                          1                750                   2800
# 4498                          1                750                   2550
# 4499                          1                750                   2900
#
#       auto_year  customer_gender_Female  customer_gender_Male  \
# 0          2006                       0                     0
# 1          2012                       0                     1
# 2          2017                       1                     0
# 3          2020                       1                     0
# 4          2018                       1                     0
# ...         ...                     ...                   ...
# 4495       2017                       0                     1
# 4496       2015                       1                     0
# 4497       2014                       0                     1
# 4498       2014                       0                     0
# 4499       2017                       1                     0
#
#       policy_state_AZ  ...  authorities_contacted_Fire  \
# 0                   0  ...                           0
# 1                   0  ...                           0
# 2                   0  ...                           0
# 3                   1  ...                           0
# 4                   0  ...                           0
# ...               ...  ...                         ...
# 4495                0  ...                           0
# 4496                0  ...                           0
# 4497                0  ...                           0
# 4498                0  ...                           0
# 4499                0  ...                           0
#
#       authorities_contacted_None  authorities_contacted_Police  \
# 0                              1                             0
# 1                              0                             1
# 2                              0                             1
# 3                              1                             0
# 4                              0                             1
# ...                          ...                           ...
# 4495                           0                             1
# 4496                           0                             1
# 4497                           0                             1
# 4498                           1                             0
# 4499                           0                             1
#
#       incident_severity_Major  incident_severity_Minor  \
# 0                           0                        1
# 1                           0                        0
# 2                           0                        1
# 3                           0                        1
# 4                           1                        0
# ...                       ...                      ...
# 4495                        1                        0
# 4496                        1                        0
# 4497                        1                        0
# 4498                        0                        1
# 4499                        0                        0
#
#       incident_severity_Totaled  incident_severity_nan  \
# 0                             0                      0
# 1                             1                      0
# 2                             0                      0
# 3                             0                      0
# 4                             0                      0
# ...                         ...                    ...
# 4495                          0                      0
# 4496                          0                      0
# 4497                          0                      0
# 4498                          0                      0
# 4499                          1                      0
#
#       police_report_available_No  police_report_available_Yes  \
# 0                              1                            0
# 1                              0                            1
# 2                              0                            1
# 3                              1                            0
# 4                              1                            0
# ...                          ...                          ...
# 4495                           1                            0
# 4496                           0                            1
# 4497                           1                            0
# 4498                           1                            0
# 4499                           0                            1
#
#       police_report_available_nan
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ...                           ...
# 4495                            0
# 4496                            0
# 4497                            0
# 4498                            0
# 4499                            0
#
# [4500 rows x 61 columns]

# %% [markdown]
# ### 기본 훈련 변수 및 하이퍼파라미터 설정

# %%
from sagemaker.xgboost.estimator import XGBoost

bucket = sagemaker_session.default_bucket()
prefix = project_prefix

estimator_output_path = f's3://{bucket}/{prefix}/training_jobs'
train_instance_count = 1

def get_pos_scale_weight(df, label):
    '''
    1, 0 의 레이블 분포를 계산하여 클래스 가중치 리턴
    예: 1: 10, 0: 90 이면 90/10 = 9 를 제공함. 
    호출:
        class_weight = get_pos_scale_weight(train_prep_df, label='fraud')
    '''
    fraud_sum = df[df[label] == 1].shape[0]
    non_fraud_sum = df[df[label] == 0].shape[0]
    class_weight = int(non_fraud_sum / fraud_sum)
    print(f"fraud_sum: {fraud_sum} , non_fraud_sum: {non_fraud_sum}, class_weight: {class_weight}")
    return class_weight
    
class_weight = get_pos_scale_weight(train_prep_df, label='fraud')


hyperparameters = {
       "scale_pos_weight" : class_weight,    
        "max_depth": "3",
        "alpha" : "0.2", 
        "eta": "0.333",
        "min_child_weight": "7",
        "objective": "binary:logistic",
        "num_round": "100",
}
# Out:
# fraud_sum: 149 , non_fraud_sum: 4351, class_weight: 29

# %% [markdown]
# # 2. 모델 훈련 코드 확인
#
# 전처리 코드는 크게 아래와 같이 구성 되어 있습니다.
# - 커맨드 인자로 전달된 변수 내용 확인
# - 훈련 데이터를 로딩 합니다.
# - xgboost의 cross-validation(cv) 로 훈련 합니다.
# - 훈련 성능을 나타내는 지표를 저장합니다.
# - 훈련이 모델 아티펙트를 저장 합니다.
#     - [알림] 일반적으로 xgboost의 알고리즘의 큰 변경이 없으면, 세이지 메이커 내장 xgboost 알고리즘을 사용합니다. 여기서는 훈련 코드를 사용자가 정의해서 사용할 수 있는 예시를 위하여 따로 훈련 코드를 만들었습니다.
# ---

# %%
# !pygmentize src/xgboost_starter_script.py

# %% [markdown]
# # 3. 모델 훈련 스텝 개발 및 실행
# ---

# %% [markdown]
# ## (1) 로컬 노트북 인스턴스에서 로컬 모드(로컬 다커 컨테이너 사용)로 훈련 코드 실행

# %%
xgb_estimator_local = XGBoost(
    entry_point = "xgboost_script.py",
    source_dir = "src",
    output_path = estimator_output_path,
    code_location = estimator_output_path,
    hyperparameters = hyperparameters,
    role = role,
    instance_count = train_instance_count,
    instance_type = 'local',
    framework_version = "1.0-1"
)
    
xgb_estimator_local.fit(inputs = {'train': train_preproc_data_uri},
                      wait=True,                        
                 )
# Out:
# Creating ikw9vfaujp-algo-1-4w1zz ...
# Creating ikw9vfaujp-algo-1-4w1zz ... done
# Attaching to ikw9vfaujp-algo-1-4w1zz
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker_xgboost_container.training:Invoking user training script.
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:Module xgboost_script does not provide a setup.py.
# ikw9vfaujp-algo-1-4w1zz | Generating setup.py
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:Generating setup.cfg
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:Generating MANIFEST.in
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:Installing module with the following command:
# ikw9vfaujp-algo-1-4w1zz | /miniconda3/bin/python3 -m pip install .
# ikw9vfaujp-algo-1-4w1zz | Processing /opt/ml/code
# ikw9vfaujp-algo-1-4w1zz | Building wheels for collected packages: xgboost-script
# ikw9vfaujp-algo-1-4w1zz |   Building wheel for xgboost-script (setup.py) ... done
# ikw9vfaujp-algo-1-4w1zz |   Created wheel for xgboost-script: filename=xgboost_script-1.0.0-py2.py3-none-any.whl size=31275 sha256=d37fbd494febfe21d9e45a1b683f6aa4dbf16bf856f8d46cb07d2384f7ed7a8c
# ikw9vfaujp-algo-1-4w1zz |   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-6r0s71nh/wheels/95/c1/85/65aaf48b35aba88c6e896d2fd04a4b69f1cee0d81ea32993ca
# ikw9vfaujp-algo-1-4w1zz | Successfully built xgboost-script
# ikw9vfaujp-algo-1-4w1zz | Installing collected packages: xgboost-script
# ikw9vfaujp-algo-1-4w1zz | Successfully installed xgboost-script-1.0.0
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# ikw9vfaujp-algo-1-4w1zz | INFO:sagemaker-containers:Invoking user script
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz | Training Env:
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz | {
# ikw9vfaujp-algo-1-4w1zz |     "additional_framework_parameters": {},
# ikw9vfaujp-algo-1-4w1zz |     "channel_input_dirs": {
# ikw9vfaujp-algo-1-4w1zz |         "train": "/opt/ml/input/data/train"
# ikw9vfaujp-algo-1-4w1zz |     },
# ikw9vfaujp-algo-1-4w1zz |     "current_host": "algo-1-4w1zz",
# ikw9vfaujp-algo-1-4w1zz |     "framework_module": "sagemaker_xgboost_container.training:main",
# ikw9vfaujp-algo-1-4w1zz |     "hosts": [
# ikw9vfaujp-algo-1-4w1zz |         "algo-1-4w1zz"
# ikw9vfaujp-algo-1-4w1zz |     ],
# ikw9vfaujp-algo-1-4w1zz |     "hyperparameters": {
# ikw9vfaujp-algo-1-4w1zz |         "scale_pos_weight": 29,
# ikw9vfaujp-algo-1-4w1zz |         "max_depth": "3",
# ikw9vfaujp-algo-1-4w1zz |         "alpha": "0.2",
# ikw9vfaujp-algo-1-4w1zz |         "eta": "0.333",
# ikw9vfaujp-algo-1-4w1zz |         "min_child_weight": "7",
# ikw9vfaujp-algo-1-4w1zz |         "objective": "binary:logistic",
# ikw9vfaujp-algo-1-4w1zz |         "num_round": "100"
# ikw9vfaujp-algo-1-4w1zz |     },
# ikw9vfaujp-algo-1-4w1zz |     "input_config_dir": "/opt/ml/input/config",
# ikw9vfaujp-algo-1-4w1zz |     "input_data_config": {
# ikw9vfaujp-algo-1-4w1zz |         "train": {
# ikw9vfaujp-algo-1-4w1zz |             "TrainingInputMode": "File"
# ikw9vfaujp-algo-1-4w1zz |         }
# ikw9vfaujp-algo-1-4w1zz |     },
# ikw9vfaujp-algo-1-4w1zz |     "input_dir": "/opt/ml/input",
# ikw9vfaujp-algo-1-4w1zz |     "is_master": true,
# ikw9vfaujp-algo-1-4w1zz |     "job_name": "sagemaker-xgboost-2021-07-25-08-58-20-970",
# ikw9vfaujp-algo-1-4w1zz |     "log_level": 20,
# ikw9vfaujp-algo-1-4w1zz |     "master_hostname": "algo-1-4w1zz",
# ikw9vfaujp-algo-1-4w1zz |     "model_dir": "/opt/ml/model",
# ikw9vfaujp-algo-1-4w1zz |     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/sagemaker-xgboost-2021-07-25-08-58-20-970/source/sourcedir.tar.gz",
# ikw9vfaujp-algo-1-4w1zz |     "module_name": "xgboost_script",
# ikw9vfaujp-algo-1-4w1zz |     "network_interface_name": "eth0",
# ikw9vfaujp-algo-1-4w1zz |     "num_cpus": 8,
# ikw9vfaujp-algo-1-4w1zz |     "num_gpus": 0,
# ikw9vfaujp-algo-1-4w1zz |     "output_data_dir": "/opt/ml/output/data",
# ikw9vfaujp-algo-1-4w1zz |     "output_dir": "/opt/ml/output",
# ikw9vfaujp-algo-1-4w1zz |     "output_intermediate_dir": "/opt/ml/output/intermediate",
# ikw9vfaujp-algo-1-4w1zz |     "resource_config": {
# ikw9vfaujp-algo-1-4w1zz |         "current_host": "algo-1-4w1zz",
# ikw9vfaujp-algo-1-4w1zz |         "hosts": [
# ikw9vfaujp-algo-1-4w1zz |             "algo-1-4w1zz"
# ikw9vfaujp-algo-1-4w1zz |         ]
# ikw9vfaujp-algo-1-4w1zz |     },
# ikw9vfaujp-algo-1-4w1zz |     "user_entry_point": "xgboost_script.py"
# ikw9vfaujp-algo-1-4w1zz | }
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz | Environment variables:
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz | SM_HOSTS=["algo-1-4w1zz"]
# ikw9vfaujp-algo-1-4w1zz | SM_NETWORK_INTERFACE_NAME=eth0
# ikw9vfaujp-algo-1-4w1zz | SM_HPS={"alpha":"0.2","eta":"0.333","max_depth":"3","min_child_weight":"7","num_round":"100","objective":"binary:logistic","scale_pos_weight":29}
# ikw9vfaujp-algo-1-4w1zz | SM_USER_ENTRY_POINT=xgboost_script.py
# ikw9vfaujp-algo-1-4w1zz | SM_FRAMEWORK_PARAMS={}
# ikw9vfaujp-algo-1-4w1zz | SM_RESOURCE_CONFIG={"current_host":"algo-1-4w1zz","hosts":["algo-1-4w1zz"]}
# ikw9vfaujp-algo-1-4w1zz | SM_INPUT_DATA_CONFIG={"train":{"TrainingInputMode":"File"}}
# ikw9vfaujp-algo-1-4w1zz | SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# ikw9vfaujp-algo-1-4w1zz | SM_CHANNELS=["train"]
# ikw9vfaujp-algo-1-4w1zz | SM_CURRENT_HOST=algo-1-4w1zz
# ikw9vfaujp-algo-1-4w1zz | SM_MODULE_NAME=xgboost_script
# ikw9vfaujp-algo-1-4w1zz | SM_LOG_LEVEL=20
# ikw9vfaujp-algo-1-4w1zz | SM_FRAMEWORK_MODULE=sagemaker_xgboost_container.training:main
# ikw9vfaujp-algo-1-4w1zz | SM_INPUT_DIR=/opt/ml/input
# ikw9vfaujp-algo-1-4w1zz | SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# ikw9vfaujp-algo-1-4w1zz | SM_OUTPUT_DIR=/opt/ml/output
# ikw9vfaujp-algo-1-4w1zz | SM_NUM_CPUS=8
# ikw9vfaujp-algo-1-4w1zz | SM_NUM_GPUS=0
# ikw9vfaujp-algo-1-4w1zz | SM_MODEL_DIR=/opt/ml/model
# ikw9vfaujp-algo-1-4w1zz | SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/sagemaker-xgboost-2021-07-25-08-58-20-970/source/sourcedir.tar.gz
# ikw9vfaujp-algo-1-4w1zz | SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1-4w1zz","framework_module":"sagemaker_xgboost_container.training:main","hosts":["algo-1-4w1zz"],"hyperparameters":{"alpha":"0.2","eta":"0.333","max_depth":"3","min_child_weight":"7","num_round":"100","objective":"binary:logistic","scale_pos_weight":29},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-xgboost-2021-07-25-08-58-20-970","log_level":20,"master_hostname":"algo-1-4w1zz","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/sagemaker-xgboost-2021-07-25-08-58-20-970/source/sourcedir.tar.gz","module_name":"xgboost_script","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1-4w1zz","hosts":["algo-1-4w1zz"]},"user_entry_point":"xgboost_script.py"}
# ikw9vfaujp-algo-1-4w1zz | SM_USER_ARGS=["--alpha","0.2","--eta","0.333","--max_depth","3","--min_child_weight","7","--num_round","100","--objective","binary:logistic","--scale_pos_weight","29"]
# ikw9vfaujp-algo-1-4w1zz | SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# ikw9vfaujp-algo-1-4w1zz | SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# ikw9vfaujp-algo-1-4w1zz | SM_HP_SCALE_POS_WEIGHT=29
# ikw9vfaujp-algo-1-4w1zz | SM_HP_MAX_DEPTH=3
# ikw9vfaujp-algo-1-4w1zz | SM_HP_ALPHA=0.2
# ikw9vfaujp-algo-1-4w1zz | SM_HP_ETA=0.333
# ikw9vfaujp-algo-1-4w1zz | SM_HP_MIN_CHILD_WEIGHT=7
# ikw9vfaujp-algo-1-4w1zz | SM_HP_OBJECTIVE=binary:logistic
# ikw9vfaujp-algo-1-4w1zz | SM_HP_NUM_ROUND=100
# ikw9vfaujp-algo-1-4w1zz | PYTHONPATH=/miniconda3/bin:/:/miniconda3/lib/python3.6/site-packages/xgboost/dmlc-core/tracker:/miniconda3/lib/python36.zip:/miniconda3/lib/python3.6:/miniconda3/lib/python3.6/lib-dynload:/miniconda3/lib/python3.6/site-packages
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz | Invoking script with the following command:
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz | /miniconda3/bin/python3 -m xgboost_script --alpha 0.2 --eta 0.333 --max_depth 3 --min_child_weight 7 --num_round 100 --objective binary:logistic --scale_pos_weight 29
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz | cv_results:     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# ikw9vfaujp-algo-1-4w1zz | 0        0.801654       0.019142       0.745448      0.042779
# ikw9vfaujp-algo-1-4w1zz | 1        0.840306       0.011155       0.783226      0.035896
# ikw9vfaujp-algo-1-4w1zz | 2        0.858308       0.010631       0.799294      0.042170
# ikw9vfaujp-algo-1-4w1zz | Refer to CloudWatch to see the following metrics
# ikw9vfaujp-algo-1-4w1zz | [0]#011train-auc:0.8583
# ikw9vfaujp-algo-1-4w1zz | [1]#011validation-auc:0.7993
# ikw9vfaujp-algo-1-4w1zz | [08:59:42] WARNING: /workspace/src/learner.cc:328:
# ikw9vfaujp-algo-1-4w1zz | Parameters: { num_round } might not be used.
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz |   This may not be accurate due to some parameters are only used in language bindings but
# ikw9vfaujp-algo-1-4w1zz |   passed down to XGBoost core.  Or some parameters are not used but slip through this
# ikw9vfaujp-algo-1-4w1zz |   verification. Please open an issue if you find above cases.
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz |
# ikw9vfaujp-algo-1-4w1zz exited with code 0
# Aborting on container exit...
# Failed to delete: /tmp/tmpx223vr4o/algo-1-4w1zz Please remove it manually.
# ===== Job Complete =====

# %% [markdown]
# ## (2) 세이지메이커 호스트 모드(로컬 다커 컨테이너 사용) 및 실험(Experiment)사용하여 훈련 코드 실행

# %% [markdown]
# ### 실험(Experiment) 세팅
# - Amazon SageMaker 실험은 기계 학습 실험을 구성, 추적, 비교 및 평가할 수 있는 Amazon SageMaker 의 기능입니다
# - 상세 사항은 개발자 가이드 참조 하세요. --> [Amazon SageMaker 실험을 통한 Machine Learning 관리](https://docs.aws.amazon.com/ko_kr/sagemaker/latest/dg/experiments.html)
# - sagemaker experiment는 추가적인 패키지를 설치하여야 합니다. 0.0.Setup-Environment 가 실행이 안도었다고 하면, `!pip install --upgrade sagemaker-experiments` 를 통해 설치 해주세요.
# - 여기서는 boto3 API를 통해서 실험을 생성합니다. SageMaker Python SDK를 통해서도 가능합니다.

# %%
# !pip install --upgrade sagemaker-experiments

from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker

from datetime import datetime

sm = boto3.client('sagemaker')


# 설험에 대한 이름을 생성 합니다.
experiment_name = project_prefix + '-single-train'

# 실험이 존재하지 않으면 생성하고, 그렇지 않으면 지나갑니다.
try:
    response = sm_client.describe_experiment(ExperimentName=experiment_name)
    print(f"Experiment:{experiment_name} already exists")    
    
except:
    response = sm_client.create_experiment(
        ExperimentName = experiment_name,
        Description = 'Experiment for fraud detection',
    )
    print(f"Experiment:{experiment_name} is created")
# Out:
# Experiment:sagemaker-pipeline-step-by-step-phase01-single-train already exists

# %% [markdown]
# ### 하이퍼 파리미터 변경 실험
# - max_depth 5개의 값을 바꾸면서 5개의 훈련잡을 실행합니다.
#     - ```for i, max_depth_num in enumerate([1,3,5,7,10]):```
#     - 만약에 리소스 제한의 에러가 발생하면, 5개를 2개 정도로 줄여서 실행 해주세요.
# - 위에서 생성한 Experiment 안에 5개의 Trial(시도) 를 생성합니다.
# - xgb_estimator 에 각각의 하이파라미터를 인자로 제공합니다.
# - xgb_estimator.fit()에 Experiment의 설정 파일을 제공합니다.
#     - 1개의 실험, 각각의 시도가 설정되어 훈련을 시작 합니다.

# %%
instance_type = 'ml.m5.xlarge'
for i, max_depth_num in enumerate([1,3,5,7,10]):
    hyperparameters = {
           "scale_pos_weight" : class_weight,    
            "max_depth": f"{max_depth_num}",
            "alpha" : "0", 
            "eta": "0.3",
            "min_child_weight": "1",
            "objective": "binary:logistic",
            "num_round": "100",
    }
    
    ts = datetime.now().strftime('%Y-%m-%d-%H-%M-%S-%f')
    trial_name = experiment_name + f"-{ts}"

    response = sm_client.create_trial(
        ExperimentName = experiment_name,
        TrialName = trial_name,
    )    
    
    experiment_config = {
        'ExperimentName' : experiment_name,
        'TrialName' : trial_name,
        "TrialComponentDisplayName" : 'Training',
    }    

    
    xgb_estimator = XGBoost(
        entry_point = "xgboost_script.py",
        source_dir = "src",
        output_path = estimator_output_path,
        code_location = estimator_output_path,
        hyperparameters = hyperparameters,
        role = role,
        instance_count = train_instance_count,
        instance_type = instance_type,
        framework_version = "1.0-1")

    xgb_estimator.fit(inputs = {'train': train_preproc_data_uri},
                          experiment_config = experiment_config,
                          wait=False,                        
                     )
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2021-07-25-08-59-44-065
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2021-07-25-08-59-44-543
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2021-07-25-08-59-44-980
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2021-07-25-08-59-50-900
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: sagemaker-xgboost-2021-07-25-08-59-51-421

# %%
## 마지막 estimator의 로그 출력
xgb_estimator.logs()
# Out:
# 2021-07-25 08:59:54 Starting - Starting the training job...
# 2021-07-25 09:00:22 Starting - Launching requested ML instancesProfilerReport-1627203591: InProgress
# ...
# 2021-07-25 09:00:51 Starting - Preparing the instances for training.........
# 2021-07-25 09:02:22 Downloading - Downloading input data
# 2021-07-25 09:02:22 Training - Downloading the training image...
# 2021-07-25 09:02:47 Uploading - Uploading generated training modelINFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Invoking user training script.
# INFO:sagemaker-containers:Module xgboost_script does not provide a setup.py.
# Generating setup.py
# INFO:sagemaker-containers:Generating setup.cfg
# INFO:sagemaker-containers:Generating MANIFEST.in
# INFO:sagemaker-containers:Installing module with the following command:
# /miniconda3/bin/python3 -m pip install .
# Processing /opt/ml/code
# Building wheels for collected packages: xgboost-script
#   Building wheel for xgboost-script (setup.py): started
#   Building wheel for xgboost-script (setup.py): finished with status 'done'
#   Created wheel for xgboost-script: filename=xgboost_script-1.0.0-py2.py3-none-any.whl size=31275 sha256=716ca631fa2ce0879e7294d3dd6f37251dc1881abffd080141d00b4fdd5524ea
#   Stored in directory: /home/model-server/tmp/pip-ephem-wheel-cache-92jgdgxc/wheels/95/c1/85/65aaf48b35aba88c6e896d2fd04a4b69f1cee0d81ea32993ca
# Successfully built xgboost-script
# Installing collected packages: xgboost-script
# Successfully installed xgboost-script-1.0.0
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker-containers:Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_xgboost_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "eta": "0.3",
#         "scale_pos_weight": 29,
#         "max_depth": "10",
#         "alpha": "0",
#         "num_round": "100",
#         "min_child_weight": "1",
#         "objective": "binary:logistic"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "sagemaker-xgboost-2021-07-25-08-59-51-421",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/sagemaker-xgboost-2021-07-25-08-59-51-421/source/sourcedir.tar.gz",
#     "module_name": "xgboost_script",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "xgboost_script.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"alpha":"0","eta":"0.3","max_depth":"10","min_child_weight":"1","num_round":"100","objective":"binary:logistic","scale_pos_weight":29}
# SM_USER_ENTRY_POINT=xgboost_script.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=xgboost_script
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_xgboost_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/sagemaker-xgboost-2021-07-25-08-59-51-421/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train"},"current_host":"algo-1","framework_module":"sagemaker_xgboost_container.training:main","hosts":["algo-1"],"hyperparameters":{"alpha":"0","eta":"0.3","max_depth":"10","min_child_weight":"1","num_round":"100","objective":"binary:logistic","scale_pos_weight":29},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"sagemaker-xgboost-2021-07-25-08-59-51-421","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/sagemaker-xgboost-2021-07-25-08-59-51-421/source/sourcedir.tar.gz","module_name":"xgboost_script","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"xgboost_script.py"}
# SM_USER_ARGS=["--alpha","0","--eta","0.3","--max_depth","10","--min_child_weight","1","--num_round","100","--objective","binary:logistic","--scale_pos_weight","29"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_ETA=0.3
# SM_HP_SCALE_POS_WEIGHT=29
# SM_HP_MAX_DEPTH=10
# SM_HP_ALPHA=0
# SM_HP_NUM_ROUND=100
# SM_HP_MIN_CHILD_WEIGHT=1
# SM_HP_OBJECTIVE=binary:logistic
# PYTHONPATH=/miniconda3/bin:/:/miniconda3/lib/python3.6/site-packages/xgboost/dmlc-core/tracker:/miniconda3/lib/python36.zip:/miniconda3/lib/python3.6:/miniconda3/lib/python3.6/lib-dynload:/miniconda3/lib/python3.6/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python3 -m xgboost_script --alpha 0 --eta 0.3 --max_depth 10 --min_child_weight 1 --num_round 100 --objective binary:logistic --scale_pos_weight 29
#
#
# cv_results:     train-auc-mean  train-auc-std  test-auc-mean  test-auc-std
# 0        0.943041       0.007943        0.78346      0.042709
# Refer to CloudWatch to see the following metrics
# [0]#011train-auc:0.943
# [1]#011validation-auc:0.7835
# [09:02:46] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
#
# 2021-07-25 09:03:23 Completed - Training job completed
# Training seconds: 56
# Billable seconds: 56

# %% [markdown]
# ###  실험 결과 보기
# 위의 실험한 결과를 확인 합니다.
# - 각각의 훈련잡의 시도에 대한 훈련 사용 데이터, 모델 입력 하이퍼 파라미터, 모델 평가 지표, 모델 아티펙트 결과 위치 등의 확인이 가능합니다.
# - **아래의 모든 내용은 SageMaker Studio 를 통해서 직관적으로 확인이 가능합니다.**

# %%
from sagemaker.analytics import ExperimentAnalytics
import pandas as pd
pd.options.display.max_columns = 50
pd.options.display.max_rows = 5
pd.options.display.max_colwidth = 50

search_expression = {
    "Filters": [
        {
            "Name": "DisplayName",
            "Operator": "Equals",
            "Value": "Training",
        }
    ],
}


trial_component_analytics = ExperimentAnalytics(
    sagemaker_session= sagemaker_session,
    experiment_name= experiment_name,
    search_expression=search_expression,
)

trial_component_analytics.dataframe()
# Out:
#                                    TrialComponentName DisplayName  \
# 0   sagemaker-xgboost-2021-07-25-08-59-44-065-aws-...    Training
# 1   sagemaker-xgboost-2021-07-25-08-59-51-421-aws-...    Training
# ..                                                ...         ...
# 23  sagemaker-xgboost-2021-07-23-02-12-54-542-aws-...    Training
# 24  sagemaker-xgboost-2021-07-23-01-43-58-289-aws-...    Training
#
#                                             SourceArn  \
# 0   arn:aws:sagemaker:ap-northeast-2:057716757052:...
# 1   arn:aws:sagemaker:ap-northeast-2:057716757052:...
# ..                                                ...
# 23  arn:aws:sagemaker:ap-northeast-2:057716757052:...
# 24  arn:aws:sagemaker:ap-northeast-2:057716757052:...
#
#                                    SageMaker.ImageUri  \
# 0   366743142698.dkr.ecr.ap-northeast-2.amazonaws....
# 1   366743142698.dkr.ecr.ap-northeast-2.amazonaws....
# ..                                                ...
# 23  366743142698.dkr.ecr.ap-northeast-2.amazonaws....
# 24  366743142698.dkr.ecr.ap-northeast-2.amazonaws....
#
#     SageMaker.InstanceCount SageMaker.InstanceType  SageMaker.VolumeSizeInGB  \
# 0                       1.0           ml.m5.xlarge                      30.0
# 1                       1.0           ml.m5.xlarge                      30.0
# ..                      ...                    ...                       ...
# 23                      1.0          ml.m5.2xlarge                      30.0
# 24                      1.0           ml.m5.xlarge                      30.0
#
#    alpha    eta max_depth min_child_weight num_round          objective  \
# 0    "0"  "0.3"       "1"              "1"     "100"  "binary:logistic"
# 1    "0"  "0.3"      "10"              "1"     "100"  "binary:logistic"
# ..   ...    ...       ...              ...       ...                ...
# 23   "0"  "0.3"       "6"              "1"     "100"  "binary:logistic"
# 24   "0"  "0.3"       "6"              "1"     "100"  "binary:logistic"
#
#     sagemaker_container_log_level  \
# 0                            20.0
# 1                            20.0
# ..                            ...
# 23                           20.0
# 24                           20.0
#
#                              sagemaker_job_name    sagemaker_program  \
# 0   "sagemaker-xgboost-2021-07-25-08-59-44-065"  "xgboost_script.py"
# 1   "sagemaker-xgboost-2021-07-25-08-59-51-421"  "xgboost_script.py"
# ..                                          ...                  ...
# 23  "sagemaker-xgboost-2021-07-23-02-12-54-542"  "xgboost_script.py"
# 24  "sagemaker-xgboost-2021-07-23-01-43-58-289"  "xgboost_script.py"
#
#     sagemaker_region                         sagemaker_submit_directory  \
# 0   "ap-northeast-2"  "s3://sagemaker-ap-northeast-2-057716757052/sa...
# 1   "ap-northeast-2"  "s3://sagemaker-ap-northeast-2-057716757052/sa...
# ..               ...                                                ...
# 23  "ap-northeast-2"  "s3://sagemaker-ap-northeast-2-057716757052/sa...
# 24  "ap-northeast-2"  "s3://sagemaker-ap-northeast-2-057716757052/sa...
#
#     scale_pos_weight  train:auc - Min  train:auc - Max  train:auc - Avg  \
# 0               29.0           0.8223           0.8223           0.8223
# 1               29.0           0.9430           0.9430           0.9430
# ..               ...              ...              ...              ...
# 23              29.0           0.9014           0.9014           0.9014
# 24              29.0           0.9014           0.9014           0.9014
#
#     train:auc - StdDev  train:auc - Last  train:auc - Count  \
# 0                  0.0            0.8223                  1
# 1                  0.0            0.9430                  1
# ..                 ...               ...                ...
# 23                 0.0            0.9014                  1
# 24                 0.0            0.9014                  1
#
#     validation:auc - Min  validation:auc - Max  validation:auc - Avg  \
# 0                 0.8160                0.8160                0.8160
# 1                 0.7835                0.7835                0.7835
# ..                   ...                   ...                   ...
# 23                0.7845                0.7845                0.7845
# 24                0.7845                0.7845                0.7845
#
#     validation:auc - StdDev  validation:auc - Last  validation:auc - Count  \
# 0                       0.0                 0.8160                       1
# 1                       0.0                 0.7835                       1
# ..                      ...                    ...                     ...
# 23                      0.0                 0.7845                       1
# 24                      0.0                 0.7845                       1
#
#    train - MediaType                                      train - Value  \
# 0               None  s3://sagemaker-ap-northeast-2-057716757052/sag...
# 1               None  s3://sagemaker-ap-northeast-2-057716757052/sag...
# ..               ...                                                ...
# 23              None  s3://sagemaker-ap-northeast-2-057716757052/sag...
# 24              None  s3://sagemaker-ap-northeast-2-057716757052/sag...
#
#    SageMaker.DebugHookOutput - MediaType  \
# 0                                   None
# 1                                   None
# ..                                   ...
# 23                                  None
# 24                                  None
#
#                     SageMaker.DebugHookOutput - Value  \
# 0   s3://sagemaker-ap-northeast-2-057716757052/sag...
# 1   s3://sagemaker-ap-northeast-2-057716757052/sag...
# ..                                                ...
# 23  s3://sagemaker-ap-northeast-2-057716757052/sag...
# 24  s3://sagemaker-ap-northeast-2-057716757052/sag...
#
#    SageMaker.ModelArtifact - MediaType  \
# 0                                 None
# 1                                 None
# ..                                 ...
# 23                                None
# 24                                None
#
#                       SageMaker.ModelArtifact - Value  \
# 0   s3://sagemaker-ap-northeast-2-057716757052/sag...
# 1   s3://sagemaker-ap-northeast-2-057716757052/sag...
# ..                                                ...
# 23  s3://sagemaker-ap-northeast-2-057716757052/sag...
# 24  s3://sagemaker-ap-northeast-2-057716757052/sag...
#
#                                                Trials  \
# 0   [sagemaker-pipeline-step-by-step-phase01-singl...
# 1   [sagemaker-pipeline-step-by-step-phase01-singl...
# ..                                                ...
# 23                 [Trial-2021-07-23-01-41-41-524747]
# 24                 [Trial-2021-07-23-01-41-41-524747]
#
#                                           Experiments
# 0   [sagemaker-pipeline-step-by-step-phase01-singl...
# 1   [sagemaker-pipeline-step-by-step-phase01-singl...
# ..                                                ...
# 23  [sagemaker-pipeline-step-by-step-phase01-singl...
# 24  [sagemaker-pipeline-step-by-step-phase01-singl...
#
# [25 rows x 39 columns]

# %% [markdown]
# ### 모델 평가 지표에 순서에 따른 시도 보기
# - 아래는 모델 평가 지표에 따른 순서로 보여주기 입니다.

# %%
trial_component_training_analytics = ExperimentAnalytics(
    sagemaker_session= sagemaker_session,
    experiment_name= experiment_name,
    search_expression=search_expression,
    sort_by="metrics.validation:auc.max",        
    sort_order="Descending",
    metric_names=["validation:auc"],
    parameter_names=["hidden_channels", "epochs", "dropout", "optimizer"],
)

trial_component_training_analytics.dataframe()
# Out:
#                                    TrialComponentName DisplayName  \
# 0   sagemaker-xgboost-2021-07-25-08-59-44-065-aws-...    Training
# 1   sagemaker-xgboost-2021-07-24-02-53-57-783-aws-...    Training
# ..                                                ...         ...
# 23  sagemaker-xgboost-2021-07-23-23-35-31-070-aws-...    Training
# 24  sagemaker-xgboost-2021-07-25-08-59-51-421-aws-...    Training
#
#                                             SourceArn  validation:auc - Min  \
# 0   arn:aws:sagemaker:ap-northeast-2:057716757052:...                0.8160
# 1   arn:aws:sagemaker:ap-northeast-2:057716757052:...                0.8160
# ..                                                ...                   ...
# 23  arn:aws:sagemaker:ap-northeast-2:057716757052:...                0.7835
# 24  arn:aws:sagemaker:ap-northeast-2:057716757052:...                0.7835
#
#     validation:auc - Max  validation:auc - Avg  validation:auc - StdDev  \
# 0                 0.8160                0.8160                      0.0
# 1                 0.8160                0.8160                      0.0
# ..                   ...                   ...                      ...
# 23                0.7835                0.7835                      0.0
# 24                0.7835                0.7835                      0.0
#
#     validation:auc - Last  validation:auc - Count train - MediaType  \
# 0                  0.8160                       1              None
# 1                  0.8160                       1              None
# ..                    ...                     ...               ...
# 23                 0.7835                       1              None
# 24                 0.7835                       1              None
#
#                                         train - Value  \
# 0   s3://sagemaker-ap-northeast-2-057716757052/sag...
# 1   s3://sagemaker-ap-northeast-2-057716757052/sag...
# ..                                                ...
# 23  s3://sagemaker-ap-northeast-2-057716757052/sag...
# 24  s3://sagemaker-ap-northeast-2-057716757052/sag...
#
#    SageMaker.DebugHookOutput - MediaType  \
# 0                                   None
# 1                                   None
# ..                                   ...
# 23                                  None
# 24                                  None
#
#                     SageMaker.DebugHookOutput - Value  \
# 0   s3://sagemaker-ap-northeast-2-057716757052/sag...
# 1   s3://sagemaker-ap-northeast-2-057716757052/sag...
# ..                                                ...
# 23  s3://sagemaker-ap-northeast-2-057716757052/sag...
# 24  s3://sagemaker-ap-northeast-2-057716757052/sag...
#
#    SageMaker.ModelArtifact - MediaType  \
# 0                                 None
# 1                                 None
# ..                                 ...
# 23                                None
# 24                                None
#
#                       SageMaker.ModelArtifact - Value  \
# 0   s3://sagemaker-ap-northeast-2-057716757052/sag...
# 1   s3://sagemaker-ap-northeast-2-057716757052/sag...
# ..                                                ...
# 23  s3://sagemaker-ap-northeast-2-057716757052/sag...
# 24  s3://sagemaker-ap-northeast-2-057716757052/sag...
#
#                                                Trials  \
# 0   [sagemaker-pipeline-step-by-step-phase01-singl...
# 1   [sagemaker-pipeline-step-by-step-phase01-singl...
# ..                                                ...
# 23  [sagemaker-pipeline-step-by-step-phase01-singl...
# 24  [sagemaker-pipeline-step-by-step-phase01-singl...
#
#                                           Experiments
# 0   [sagemaker-pipeline-step-by-step-phase01-singl...
# 1   [sagemaker-pipeline-step-by-step-phase01-singl...
# ..                                                ...
# 23  [sagemaker-pipeline-step-by-step-phase01-singl...
# 24  [sagemaker-pipeline-step-by-step-phase01-singl...
#
# [25 rows x 17 columns]

# %% [markdown]
# ## (3) SageMaker Pipeline에서  실행
# - 모델 훈련 스텝과 모델 등록 스텝 두가지를 실행합니다.
#
# ---

# %% [markdown]
# ### 모델 빌딩 파이프라인 변수 생성

# %%
from sagemaker.workflow.parameters import (
    ParameterInteger,
    ParameterString,
)

processing_instance_count = ParameterInteger(
    name="ProcessingInstanceCount",
    default_value=1
)
processing_instance_type = ParameterString(
    name="ProcessingInstanceType",
    default_value="ml.m5.xlarge"
)

training_instance_type = ParameterString(
    name="TrainingInstanceType",
    default_value="ml.m5.xlarge"
)


training_instance_count = ParameterInteger(
    name="TrainInstanceCount",
    default_value=1
)

model_approval_status = ParameterString(
    name="ModelApprovalStatus", default_value="PendingManualApproval"
)


input_data = ParameterString(
    name="InputData",
    default_value=input_data_uri,
)

# %% [markdown]
# ### 모델 학습을 위한 학습단계 정의
#
# 본 단계에서는 SageMaker의 [XGBoost](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost.html) 알고리즘을 이용하여 학습을 진행할 것입니다. XGBoost 알고리즘을 이용하도록 Estimator를 구성합니다. 보편적인 학습스크립트를 이용하여 입력 채널에서 정의한 학습데이터를 로드하고, 하이퍼파라미터 설정을 통해 학습을 설정하고, 모델을 학습한 후 `model_dir`경로에 학습된 모델을 저장합니다. 저장된 모델은 이후 호스팅을 위해 사용됩니다.
#
# 학습된 모델이 추출되어 저장될 경로 또한 명시되었습니다.
#
# `training_instance_type`파라미터가 사용된 것을 확인합니다. 이 값은 본 예제의 파이프라인에서 여러번 사용됩니다. 본 단계에서는 estimator를 선언할 때 전달되었습니다.

# %%
hyperparameters = {
       "scale_pos_weight" : class_weight,    
        "max_depth": "3",
        "alpha" : "0", 
        "eta": "0.3",
        "min_child_weight": "1",
        "objective": "binary:logistic",
        "num_round": "100",
}


xgb_train = XGBoost(
    entry_point = "xgboost_script.py",
    source_dir = "src",
    output_path = estimator_output_path,
    code_location = estimator_output_path,
    hyperparameters = hyperparameters,
    role = role,
    instance_count = train_instance_count,
    instance_type = training_instance_type,
    framework_version = "1.0-1")

# %% [markdown]
# 이전 단계에서 (프로세싱) 전처리 훈련, 검증 데이터 세트를 입력으로 제공 합니다.

# %%
from sagemaker.inputs import TrainingInput
from sagemaker.workflow.steps import TrainingStep


step_train = TrainingStep(
    name="FraudScratchTrain",
    estimator=xgb_train,
    inputs={
        "train": TrainingInput(
            s3_data= train_preproc_data_uri,
            content_type="text/csv"
        ),
    },
)

# %% [markdown]
# ### 모델 등록 스텝
# - 모델 등록 단계의 개발자 가이드
#     - [모델 등록기 단계](https://docs.aws.amazon.com/ko_kr/sagemaker/latest/dg/build-and-manage-steps.html#step-type-register-model)
#     - [모델 레지스트리로 모델 등록 및 배포](https://docs.aws.amazon.com/ko_kr/sagemaker/latest/dg/model-registry.html)
# - 모델 그룹 릭스팅 API:  [ListModelPackageGroups](https://docs.aws.amazon.com/sagemaker/latest/APIReference/API_ListModelPackageGroups.html)

# %%
model_package_group_name = f"{project_prefix}"
model_package_group_input_dict = {
 "ModelPackageGroupName" : model_package_group_name,
 "ModelPackageGroupDescription" : "Sample model package group"
}

model_approval_status = ParameterString(
    name="ModelApprovalStatus", default_value="PendingManualApproval"
)

from sagemaker.workflow.step_collections import RegisterModel

step_register = RegisterModel(
    name= f"{project_prefix}-XgboostRegisterModel",
    estimator=xgb_train,
    image_uri= step_train.properties.AlgorithmSpecification.TrainingImage,
    model_data= step_train.properties.ModelArtifacts.S3ModelArtifacts,    
    content_types=["text/csv"],
    response_types=["text/csv"],
    inference_instances=["ml.t2.medium", "ml.m5.xlarge"],
    transform_instances=["ml.m5.xlarge"],
    model_package_group_name=model_package_group_name,
    approval_status=model_approval_status,
    #model_metrics=model_metrics,
)

# %% [markdown]
# ### 모델 빌딩 파이프라인 정의

# %%
from sagemaker.workflow.pipeline import Pipeline

from sagemaker.workflow.execution_variables import ExecutionVariables
from sagemaker.workflow.pipeline_experiment_config import PipelineExperimentConfig


pipeline_name = project_prefix
pipeline = Pipeline(
    name=pipeline_name,
    parameters=[
        processing_instance_type, 
        processing_instance_count,
        training_instance_type,        
        input_data,
        model_approval_status,
    ],
    pipeline_experiment_config=PipelineExperimentConfig(
      ExecutionVariables.PIPELINE_NAME,
      ExecutionVariables.PIPELINE_EXECUTION_ID
    ),    
    steps=[step_train, step_register],
)

# %%
import json

definition = json.loads(pipeline.definition())
# definition
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# WARNING:sagemaker.estimator:No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config

# %% [markdown]
# ### 파이프라인을 SageMaker에 제출하고 실행하기
#
# 파이프라인 정의를 파이프라인 서비스에 제출합니다. 함께 전달되는 역할(role)을 이용하여 AWS에서 파이프라인을 생성하고 작업의 각 단계를 실행할 것입니다.

# %%
pipeline.upsert(role_arn=role)
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# WARNING:sagemaker.estimator:No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# WARNING:sagemaker.estimator:No finished training job found associated with this estimator. Please make sure this estimator is only used for building workflow config
# {'PipelineArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:pipeline/sagemaker-pipeline-step-by-step-phase01',
#  'ResponseMetadata': {'RequestId': 'ca6b4a20-b307-4487-8c82-c9957a9785f9',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'ca6b4a20-b307-4487-8c82-c9957a9785f9',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '112',
#    'date': 'Sun, 25 Jul 2021 10:36:04 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# 디폴트값을 이용하여 파이프라인을 샐행합니다.

# %%
execution = pipeline.start()

# %% [markdown]
# ### 파이프라인 운영: 파이프라인 대기 및 실행상태 확인
#
# 워크플로우의 실행상황을 살펴봅니다.

# %%
execution.describe()
# Out:
# {'PipelineArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:pipeline/sagemaker-pipeline-step-by-step-phase01',
#  'PipelineExecutionArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:pipeline/sagemaker-pipeline-step-by-step-phase01/execution/w5kkuicskpm0',
#  'PipelineExecutionDisplayName': 'execution-1627209365868',
#  'PipelineExecutionStatus': 'Executing',
#  'PipelineExperimentConfig': {'ExperimentName': 'sagemaker-pipeline-step-by-step-phase01',
#   'TrialName': 'w5kkuicskpm0'},
#  'CreationTime': datetime.datetime(2021, 7, 25, 10, 36, 5, 721000, tzinfo=tzlocal()),
#  'LastModifiedTime': datetime.datetime(2021, 7, 25, 10, 36, 5, 721000, tzinfo=tzlocal()),
#  'CreatedBy': {},
#  'LastModifiedBy': {},
#  'ResponseMetadata': {'RequestId': 'c08184bb-0846-4294-bc3e-863ab4c359c7',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'c08184bb-0846-4294-bc3e-863ab4c359c7',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '568',
#    'date': 'Sun, 25 Jul 2021 10:36:05 GMT'},
#   'RetryAttempts': 0}}

# %%
execution.wait()

# %% [markdown]
# 실행이 완료될 때까지 기다립니다.

# %% [markdown]
# 실행된 단계들을 리스트업합니다. 파이프라인의 단계실행 서비스에 의해 시작되거나 완료된 단계를 보여줍니다.

# %%
execution.list_steps()
# Out:
# [{'StepName': 'sagemaker-pipeline-step-by-step-phase01-XgboostRegisterModel',
#   'StartTime': datetime.datetime(2021, 7, 25, 10, 39, 28, 895000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 7, 25, 10, 39, 29, 571000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'RegisterModel': {'Arn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/5'}}},
#  {'StepName': 'FraudScratchTrain',
#   'StartTime': datetime.datetime(2021, 7, 25, 10, 36, 6, 847000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 7, 25, 10, 39, 28, 165000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'TrainingJob': {'Arn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:training-job/pipelines-w5kkuicskpm0-fraudscratchtrain-cvlch1ewiy'}}}]

# %% [markdown]
# ## 모델 레지스트리에서 모델 등록 확인
# - 등록된 모델 버전에 대한 보기 --> [모델 버전의 세부 정보 보기](https://docs.aws.amazon.com/ko_kr/sagemaker/latest/dg/model-registry-details.html)

# %%
# 위에서 생성한 model_package_group_name 을 인자로 제공 합니다.
response = sm_client.list_model_packages(ModelPackageGroupName= model_package_group_name)
response
# Out:
# {'ModelPackageSummaryList': [{'ModelPackageGroupName': 'sagemaker-pipeline-step-by-step-phase01',
#    'ModelPackageVersion': 5,
#    'ModelPackageArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/5',
#    'CreationTime': datetime.datetime(2021, 7, 25, 10, 39, 29, 449000, tzinfo=tzlocal()),
#    'ModelPackageStatus': 'Completed',
#    'ModelApprovalStatus': 'PendingManualApproval'},
#   {'ModelPackageGroupName': 'sagemaker-pipeline-step-by-step-phase01',
#    'ModelPackageVersion': 4,
#    'ModelPackageArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/4',
#    'CreationTime': datetime.datetime(2021, 7, 25, 9, 10, 35, 657000, tzinfo=tzlocal()),
#    'ModelPackageStatus': 'Completed',
#    'ModelApprovalStatus': 'PendingManualApproval'},
#   {'ModelPackageGroupName': 'sagemaker-pipeline-step-by-step-phase01',
#    'ModelPackageVersion': 3,
#    'ModelPackageArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/3',
#    'CreationTime': datetime.datetime(2021, 7, 24, 7, 15, 8, 254000, tzinfo=tzlocal()),
#    'ModelPackageStatus': 'Completed',
#    'ModelApprovalStatus': 'PendingManualApproval'},
#   {'ModelPackageGroupName': 'sagemaker-pipeline-step-by-step-phase01',
#    'ModelPackageVersion': 2,
#    'ModelPackageArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/2',
#    'CreationTime': datetime.datetime(2021, 7, 24, 2, 58, 24, 213000, tzinfo=tzlocal()),
#    'ModelPackageStatus': 'Completed',
#    'ModelApprovalStatus': 'PendingManualApproval'},
#   {'ModelPackageGroupName': 'sagemaker-pipeline-step-by-step-phase01',
#    'ModelPackageVersion': 1,
#    'ModelPackageArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/1',
#    'CreationTime': datetime.datetime(2021, 7, 24, 1, 17, 56, 82000, tzinfo=tzlocal()),
#    'ModelPackageStatus': 'Completed',
#    'ModelApprovalStatus': 'Approved'}],
#  'ResponseMetadata': {'RequestId': '4df5daa7-2e22-4ddc-83b4-d1940c1697ee',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '4df5daa7-2e22-4ddc-83b4-d1940c1697ee',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1641',
#    'date': 'Sun, 25 Jul 2021 10:39:37 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# 등록된 모델 버전의 상세 정보를 제공합니다.

# %%
ModelPackageArn = response['ModelPackageSummaryList'][0]['ModelPackageArn']
sm_client.describe_model_package(ModelPackageName=ModelPackageArn)
# Out:
# {'ModelPackageGroupName': 'sagemaker-pipeline-step-by-step-phase01',
#  'ModelPackageVersion': 5,
#  'ModelPackageArn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/5',
#  'CreationTime': datetime.datetime(2021, 7, 25, 10, 39, 29, 449000, tzinfo=tzlocal()),
#  'InferenceSpecification': {'Containers': [{'Image': '366743142698.dkr.ecr.ap-northeast-2.amazonaws.com/sagemaker-xgboost:1.0-1-cpu-py3',
#     'ImageDigest': 'sha256:04889b02181f14632e19ef6c2a7d74bfe699ff4c7f44669a78834bc90b77fe5a',
#     'ModelDataUrl': 's3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/pipelines-w5kkuicskpm0-FraudScratchTrain-CVLCH1ewIy/output/model.tar.gz'}],
#   'SupportedTransformInstanceTypes': ['ml.m5.xlarge'],
#   'SupportedRealtimeInferenceInstanceTypes': ['ml.t2.medium', 'ml.m5.xlarge'],
#   'SupportedContentTypes': ['text/csv'],
#   'SupportedResponseMIMETypes': ['text/csv']},
#  'ModelPackageStatus': 'Completed',
#  'ModelPackageStatusDetails': {'ValidationStatuses': [],
#   'ImageScanStatuses': []},
#  'CertifyForMarketplace': False,
#  'ModelApprovalStatus': 'PendingManualApproval',
#  'MetadataProperties': {'GeneratedBy': 'arn:aws:sagemaker:ap-northeast-2:057716757052:pipeline/sagemaker-pipeline-step-by-step-phase01/execution/w5kkuicskpm0'},
#  'ResponseMetadata': {'RequestId': 'b550b5ff-cbba-4776-9d54-db8169aeaf73',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'b550b5ff-cbba-4776-9d54-db8169aeaf73',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1202',
#    'date': 'Sun, 25 Jul 2021 10:39:37 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### 아티펙트 경로 추출
# 위의 훈련 스텝이 완료되면 실행해주세요

# %%
from IPython.display import display as dp
def get_train_artifact(execution, client, job_type,  kind=0):
    '''
    kind: 0 --> train
    kind: 2 --> test
    '''
    response = execution.list_steps()
    dp("response: ", response)
    proc_arn = response[1]['Metadata'][job_type]['Arn'] # 1은 훈련 스텝
    train_job_name = proc_arn.split('/')[-1]
    # print("train_job_name: ", train_job_name)
    response = client.describe_training_job(TrainingJobName = train_job_name)
    # print("\nresponse: ", response)    
    train_model_artifact = response['ModelArtifacts']['S3ModelArtifacts']    
    
    return train_model_artifact

import boto3
client = boto3.client("sagemaker")
    
train_model_artifact = get_train_artifact(execution, client,job_type='TrainingJob', kind=0)
print(" train_model_artifact: ", train_model_artifact)
# Out:
# 'response: '
# [{'StepName': 'sagemaker-pipeline-step-by-step-phase01-XgboostRegisterModel',
#   'StartTime': datetime.datetime(2021, 7, 25, 10, 39, 28, 895000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 7, 25, 10, 39, 29, 571000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'RegisterModel': {'Arn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:model-package/sagemaker-pipeline-step-by-step-phase01/5'}}},
#  {'StepName': 'FraudScratchTrain',
#   'StartTime': datetime.datetime(2021, 7, 25, 10, 36, 6, 847000, tzinfo=tzlocal()),
#   'EndTime': datetime.datetime(2021, 7, 25, 10, 39, 28, 165000, tzinfo=tzlocal()),
#   'StepStatus': 'Succeeded',
#   'Metadata': {'TrainingJob': {'Arn': 'arn:aws:sagemaker:ap-northeast-2:057716757052:training-job/pipelines-w5kkuicskpm0-fraudscratchtrain-cvlch1ewiy'}}}]
#  train_model_artifact:  s3://sagemaker-ap-northeast-2-057716757052/sagemaker-pipeline-step-by-step-phase01/training_jobs/pipelines-w5kkuicskpm0-FraudScratchTrain-CVLCH1ewIy/output/model.tar.gz

# %%
image_uri = xgb_train.image_uri

# %% [markdown]
# 훈련 모델 아티펙트와, 훈련시 사용한 다커 이미지의 경로를 저장 합니다.

# %%
# %store train_model_artifact
# %store image_uri
# Out:
# Stored 'train_model_artifact' (str)
# Stored 'image_uri' (str)
